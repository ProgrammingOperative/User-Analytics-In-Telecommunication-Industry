# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
user_data = pd.read_csv('../../data/Week1_challenge_data_source(CSV).csv')
user_data.head()
# Out:
#       Bearer Id            Start  Start ms              End  End ms  \
# 0  1.311448e+19   4/4/2019 12:01     770.0  4/25/2019 14:35   662.0
# 1  1.311448e+19   4/9/2019 13:04     235.0   4/25/2019 8:15   606.0
# 2  1.311448e+19   4/9/2019 17:42       1.0  4/25/2019 11:58   652.0
# 3  1.311448e+19   4/10/2019 0:31     486.0   4/25/2019 7:36   171.0
# 4  1.311448e+19  4/12/2019 20:10     565.0  4/25/2019 10:40   954.0
#
#    Dur. (ms)          IMSI  MSISDN/Number          IMEI  \
# 0  1823652.0  2.082014e+14   3.366496e+10  3.552121e+13
# 1  1365104.0  2.082019e+14   3.368185e+10  3.579401e+13
# 2  1361762.0  2.082003e+14   3.376063e+10  3.528151e+13
# 3  1321509.0  2.082014e+14   3.375034e+10  3.535661e+13
# 4  1089009.0  2.082014e+14   3.369980e+10  3.540701e+13
#
#       Last Location Name  ...  Youtube DL (Bytes)  Youtube UL (Bytes)  \
# 0  9.16456699548519E+015  ...          15854611.0           2501332.0
# 1                L77566A  ...          20247395.0          19111729.0
# ...

# %%
user_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150001 entries, 0 to 150000
# Data columns (total 55 columns):
#  #   Column                                    Non-Null Count   Dtype
# ---  ------                                    --------------   -----
#  0   Bearer Id                                 149010 non-null  float64
#  1   Start                                     150000 non-null  object
#  2   Start ms                                  150000 non-null  float64
#  3   End                                       150000 non-null  object
#  4   End ms                                    150000 non-null  float64
#  5   Dur. (ms)                                 150000 non-null  float64
#  6   IMSI                                      149431 non-null  float64
#  7   MSISDN/Number                             148935 non-null  float64
#  8   IMEI                                      149429 non-null  float64
#  9   Last Location Name                        148848 non-null  object
# ...

# %%
user_data.columns.to_list
# Out:
# <bound method IndexOpsMixin.tolist of Index(['Bearer Id', 'Start', 'Start ms', 'End', 'End ms', 'Dur. (ms)', 'IMSI',
#        'MSISDN/Number', 'IMEI', 'Last Location Name', 'Avg RTT DL (ms)',
#        'Avg RTT UL (ms)', 'Avg Bearer TP DL (kbps)', 'Avg Bearer TP UL (kbps)',
#        'TCP DL Retrans. Vol (Bytes)', 'TCP UL Retrans. Vol (Bytes)',
#        'DL TP < 50 Kbps (%)', '50 Kbps < DL TP < 250 Kbps (%)',
#        '250 Kbps < DL TP < 1 Mbps (%)', 'DL TP > 1 Mbps (%)',
#        'UL TP < 10 Kbps (%)', '10 Kbps < UL TP < 50 Kbps (%)',
#        '50 Kbps < UL TP < 300 Kbps (%)', 'UL TP > 300 Kbps (%)',
#        'HTTP DL (Bytes)', 'HTTP UL (Bytes)', 'Activity Duration DL (ms)',
#        'Activity Duration UL (ms)', 'Dur. (ms).1', 'Handset Manufacturer',
#        'Handset Type', 'Nb of sec with 125000B < Vol DL',
#        'Nb of sec with 1250B < Vol UL < 6250B',
#        'Nb of sec with 31250B < Vol DL < 125000B',
#        'Nb of sec with 37500B < Vol UL',
# ...

# %%
user_data.dtypes
# Out:
# Bearer_Id                                   float64
# Start                                        object
# Start_ms                                    float64
# End                                          object
# End_ms                                      float64
# Dur_ms                                      float64
# IMSI                                        float64
# MSISDN_Number                               float64
# IMEI                                        float64
# Last_Location_Name                           object
# Avg_RTT_DL_(ms)                             float64
# Avg_RTT_UL_(ms)                             float64
# Avg_Bearer_TP_DL_(kbps)                     float64
# Avg_Bearer_TP_UL_(kbps)                     float64
# TCP_DL_Retrans_Vol_(Bytes)                  float64
# TCP_UL_Retrans_Vol_(Bytes)                  float64
# DL_TP_<_50_Kbps_(%)                         float64
# 50_Kbps_<_DL_TP_<_250_Kbps_(%)              float64
# ...

# %% [markdown]
# Rewrite the column names by removing the empty spaces between them

# %%
user_data.columns = ['Bearer_Id','Start', 'Start_ms', 'End', 'End_ms', 'Dur_ms', 'IMSI', 'MSISDN_Number', 'IMEI',
                    'Last_Location_Name', 'Avg_RTT_DL_(ms)', 'Avg_RTT_UL_(ms)', 'Avg_Bearer_TP_DL_(kbps)','Avg_Bearer_TP_UL_(kbps)',
                     'TCP_DL_Retrans_Vol_(Bytes)', 'TCP_UL_Retrans_Vol_(Bytes)', 'DL_TP_<_50_Kbps_(%)',
                     '50_Kbps_<_DL_TP_<_250_Kbps_(%)', '250_Kbps_<_DL_TP_<_1_Mbps_(%)', 'DL_TP_>_1_Mbps_(%)',
                     'UL_TP_<_10_Kbps_(%)', '10_Kbps_<_UL_TP_<_50_Kbps_(%)', '50_Kbps_<_UL_TP_<_300_Kbps_(%)',
                     'UL_TP_>_300_Kbps_(%)', 'HTTP_DL_(Bytes)', 'HTTP_UL_(Bytes)', 'Activity_Duration_DL_(ms)',
                     'Activity_Duration_UL_(ms)', 'Dur_(ms)_1', 'Handset_Manufacturer', 'Handset_Type',
                     'Nb_of_sec_with_125000B_<_Vol_DL', 'Nb_of_sec_with_1250B_<_Vol_UL_<_6250B', 'Nb_of_sec_with_31250B_<_Vol_DL_<_125000B',
                     'Nb_of_sec_with_37500B_<_Vol UL', 'Nb_of_sec_with_6250B_<_Vol_DL_<_31250B', 
                     'Nb_of_sec_with_6250B_<_Vol_UL_<_37500B', 'Nb_of_sec_with_Vol_DL_<_6250B', 
                    'Nb_of_sec_with_Vol_UL_<_1250B', 'Social_Media_DL_(Bytes)', 'Social_Media_UL_(Bytes)',
                     'Google_DL_(Bytes)', 'Google_UL_(Bytes)', 'Email_DL(Bytes)', 'Email_UL(Bytes)', 
                     'Youtube_DL_(Bytes)', 'Youtube_UL_(Bytes)', 'Netflix_DL_(Bytes)', 'Netflix_UL_(Bytes)',
                     'Gaming_DL_(Bytes)', 'Gaming_UL_(Bytes)', 'Other_DL_(Bytes)', 'Other_UL_(Bytes)',
                     'Total_UL_(Bytes)','Total_DL_(Bytes)'
                    ]

# %%
#Determining the number of data points
print(f" There are {user_data.shape[0]} rows and {user_data.shape[1]} columns")
# Out:
#  There are 150001 rows and 55 columns

# %%
#Checking whether there are errors in the data
print("The number of missing value(s): {}".format(user_data.isnull().sum()))
print("Columns having missing columns value:{}".format(user_data.columns[user_data.isnull().any()]))
# Out:
# The number of missing value(s): Bearer_Id                                   0
# Start                                       0
# Start_ms                                    0
# End                                         0
# End_ms                                      0
# Dur_ms                                      0
# IMSI                                        0
# MSISDN_Number                               0
# IMEI                                        0
# Last_Location_Name                          0
# Avg_RTT_DL_(ms)                             0
# Avg_RTT_UL_(ms)                             0
# Avg_Bearer_TP_DL_(kbps)                     0
# Avg_Bearer_TP_UL_(kbps)                     0
# TCP_DL_Retrans_Vol_(Bytes)                  0
# TCP_UL_Retrans_Vol_(Bytes)                  0
# DL_TP_<_50_Kbps_(%)                         0
# 50_Kbps_<_DL_TP_<_250_Kbps_(%)              0
# 250_Kbps_<_DL_TP_<_1_Mbps_(%)               0
# DL_TP_>_1_Mbps_(%)                          0
# ...

# %%
#Filling the cells having null value with the mean of their respective columns
user_data.fillna(user_data.mean().round(1), inplace=True)
# Out:
# /tmp/ipykernel_6226/434003163.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   user_data.fillna(user_data.mean().round(1), inplace=True)

# %%
print("The number of missing value(s): {}".format(user_data.isnull().sum().sum()))
print("Columns having missing columns value:{}".format(user_data.columns[user_data.isnull().any()]))
# Out:
# The number of missing value(s): 2299
# Columns having missing columns value:Index(['Start', 'End', 'Last_Location_Name', 'Handset_Manufacturer',
#        'Handset_Type'],
#       dtype='object')

# %%
#Checking for columns with null values
user_data.isna().sum()
# Out:
# Bearer_Id                                      0
# Start                                          1
# Start_ms                                       0
# End                                            1
# End_ms                                         0
# Dur_ms                                         0
# IMSI                                           0
# MSISDN_Number                                  0
# IMEI                                           0
# Last_Location_Name                          1153
# Avg_RTT_DL_(ms)                                0
# Avg_RTT_UL_(ms)                                0
# Avg_Bearer_TP_DL_(kbps)                        0
# Avg_Bearer_TP_UL_(kbps)                        0
# TCP_DL_Retrans_Vol_(Bytes)                     0
# TCP_UL_Retrans_Vol_(Bytes)                     0
# DL_TP_<_50_Kbps_(%)                            0
# 50_Kbps_<_DL_TP_<_250_Kbps_(%)                 0
# 250_Kbps_<_DL_TP_<_1_Mbps_(%)                  0
# ...

# %%
'''Fill the null values of the remaining columns with the respective column mode'''
for i in ['Start', 'End', 'Last_Location_Name', 'Handset_Manufacturer', 'Handset_Type']:
    user_data[i] = user_data[i].fillna(user_data[i].mode()[0])

# %%
print("The number of missing value(s): {}".format(user_data.isnull().sum().sum()))
print("Columns having missing columns value:{}".format(user_data.columns[user_data.isnull().any()]))
# Out:
# The number of missing value(s): 0
# Columns having missing columns value:Index([], dtype='object')

# %%
user_data.isna().sum()
# Out:
# Bearer_Id                                   0
# Start                                       0
# Start_ms                                    0
# End                                         0
# End_ms                                      0
# Dur_ms                                      0
# IMSI                                        0
# MSISDN_Number                               0
# IMEI                                        0
# Last_Location_Name                          0
# Avg_RTT_DL_(ms)                             0
# Avg_RTT_UL_(ms)                             0
# Avg_Bearer_TP_DL_(kbps)                     0
# Avg_Bearer_TP_UL_(kbps)                     0
# TCP_DL_Retrans_Vol_(Bytes)                  0
# TCP_UL_Retrans_Vol_(Bytes)                  0
# DL_TP_<_50_Kbps_(%)                         0
# 50_Kbps_<_DL_TP_<_250_Kbps_(%)              0
# 250_Kbps_<_DL_TP_<_1_Mbps_(%)               0
# DL_TP_>_1_Mbps_(%)                          0
# ...

# %%
user_data.head()
# Out:
#       Bearer_Id            Start  Start_ms              End  End_ms  \
# 0  1.311448e+19   4/4/2019 12:01     770.0  4/25/2019 14:35   662.0
# 1  1.311448e+19   4/9/2019 13:04     235.0   4/25/2019 8:15   606.0
# 2  1.311448e+19   4/9/2019 17:42       1.0  4/25/2019 11:58   652.0
# 3  1.311448e+19   4/10/2019 0:31     486.0   4/25/2019 7:36   171.0
# 4  1.311448e+19  4/12/2019 20:10     565.0  4/25/2019 10:40   954.0
#
#       Dur_ms          IMSI  MSISDN_Number          IMEI  \
# 0  1823652.0  2.082014e+14   3.366496e+10  3.552121e+13
# 1  1365104.0  2.082019e+14   3.368185e+10  3.579401e+13
# 2  1361762.0  2.082003e+14   3.376063e+10  3.528151e+13
# 3  1321509.0  2.082014e+14   3.375034e+10  3.535661e+13
# 4  1089009.0  2.082014e+14   3.369980e+10  3.540701e+13
#
#       Last_Location_Name  ...  Youtube_DL_(Bytes)  Youtube_UL_(Bytes)  \
# 0  9.16456699548519E+015  ...          15854611.0           2501332.0
# 1                L77566A  ...          20247395.0          19111729.0
# ...

# %%
plot_count(user_data, 'Handset_Type')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/wacira/Sprint December/Resources/Week 1 - User Analysis in Telecommunication Industry/User-Analytics-In-Telecommunication-Industry/notebooks/User Analytics In Telecommunication Industry.ipynb Cell 16 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/wacira/Sprint%20December/Resources/Week%201%20-%20User%20Analysis%20in%20Telecommunication%20Industry/User-Analytics-In-Telecommunication-Industry/notebooks/User%20Analytics%20In%20Telecommunication%20Industry.ipynb#X21sZmlsZQ%3D%3D?line=0'>1</a> plot_count(user_data, 'Handset_Type')
#
# NameError: name 'plot_count' is not defined

# %%
#Determining the frequency of the top 10 Handset types used in the data
handset_frequency = user_data['Handset_Type'].value_counts()
handset_frequency[0:10]
# Out:
# Huawei B528S-23A                20324
# Apple iPhone 6S (A1688)          9419
# Apple iPhone 6 (A1586)           9023
# undefined                        8987
# Apple iPhone 7 (A1778)           6326
# Apple iPhone Se (A1723)          5187
# Apple iPhone 8 (A1905)           4993
# Apple iPhone Xr (A2105)          4568
# Samsung Galaxy S8 (Sm-G950F)     4520
# Apple iPhone X (A1901)           3813
# Name: Handset_Type, dtype: int64

# %%
#Top 3 handset manufacturers
top_3_handset_manufacturers = user_data['Handset_Manufacturer'].value_counts()[:3]
top_3_handset_manufacturers
# Out:
# Apple      60137
# Samsung    40839
# Huawei     34423
# Name: Handset_Manufacturer, dtype: int64

# %%
#Top 5 handsets per top 3 manufactures i.e Apple, Samsung, Huawei
handset_manufacturer_group = user_data.groupby(['Handset_Manufacturer'])

for i in ['Apple', 'Samsung', 'Huawei']:
    print(i)
    print(handset_manufacturer_group.get_group(i)['Handset_Type'].value_counts()[0:5])
    print("")
# Out:
# Apple
# Apple iPhone 6S (A1688)    9419
# Apple iPhone 6 (A1586)     9023
# Apple iPhone 7 (A1778)     6326
# Apple iPhone Se (A1723)    5187
# Apple iPhone 8 (A1905)     4993
# Name: Handset_Type, dtype: int64
#
# Samsung
# Samsung Galaxy S8 (Sm-G950F)    4520
# Samsung Galaxy A5 Sm-A520F      3724
# Samsung Galaxy J5 (Sm-J530)     3696
# Samsung Galaxy J3 (Sm-J330)     3484
# Samsung Galaxy S7 (Sm-G930X)    3199
# Name: Handset_Type, dtype: int64
#
# Huawei
# Huawei B528S-23A                  19752
# Huawei E5180                       2079
# Huawei P20 Lite Huawei Nova 3E     2021
# Huawei P20                         1480
# Huawei Y6 2018                      997
# Name: Handset_Type, dtype: int64

# %% [markdown]
# ### Recommendation to the marketing Team:
#
# It should target the Apple manufacturers as they have more users in their telecommunication market
#
# Also, they should focus their efforts on the *Huawei B528S-23A* handset type as it has the most
# number of engaged users

# %%
#Creating a clean csv file before further analysis
user_data.to_csv('../data/clean_data.csv',index=False)

# %%
clean_data = pd.read_csv('../data/clean_data.csv')
clean_data
# Out:
#            Bearer_Id            Start  Start_ms              End  End_ms  \
# 0       1.311448e+19   4/4/2019 12:01     770.0  4/25/2019 14:35   662.0
# 1       1.311448e+19   4/9/2019 13:04     235.0   4/25/2019 8:15   606.0
# 2       1.311448e+19   4/9/2019 17:42       1.0  4/25/2019 11:58   652.0
# 3       1.311448e+19   4/10/2019 0:31     486.0   4/25/2019 7:36   171.0
# 4       1.311448e+19  4/12/2019 20:10     565.0  4/25/2019 10:40   954.0
# ...              ...              ...       ...              ...     ...
# 149996  7.277826e+18   4/29/2019 7:28     451.0   4/30/2019 6:02   214.0
# 149997  7.349883e+18   4/29/2019 7:28     483.0  4/30/2019 10:41   187.0
# 149998  1.311448e+19   4/29/2019 7:28     283.0  4/30/2019 10:46   810.0
# 149999  1.311448e+19   4/29/2019 7:28     696.0  4/30/2019 10:40   327.0
# 150000  1.013887e+19   4/26/2019 7:25     499.2   4/25/2019 0:01   498.8
#
#            Dur_ms          IMSI  MSISDN_Number          IMEI  \
# ...

# %%
'''Aggregate per user using the selected columns as below - Including creating of new rows and 
changing the the display of the data to float of one decimal place
'''


pd.set_option('display.float_format', lambda x: '%.1f' % x)

clean_data['Total_UL_and_DL_(Bytes)'] = clean_data['Total_UL_(Bytes)'] + clean_data['Total_DL_(Bytes)']
clean_data['Other_UL_and_DL_(Bytes)'] = clean_data['Other_UL_(Bytes)'] + clean_data['Other_DL_(Bytes)']
clean_data['Gaming_UL_and_DL_(Bytes)'] = clean_data['Gaming_UL_(Bytes)'] + clean_data['Gaming_DL_(Bytes)']
clean_data['Netflix_UL_and_DL_(Bytes)'] = clean_data['Netflix_UL_(Bytes)'] + clean_data['Netflix_DL_(Bytes)']
clean_data['Youtube_UL_and_DL_(Bytes)'] = clean_data['Youtube_UL_(Bytes)'] + clean_data['Youtube_DL_(Bytes)']
clean_data['Email_UL_and_DL_(Bytes)'] = clean_data['Email_UL(Bytes)'] + clean_data['Email_DL(Bytes)']
clean_data['Google_UL_and_DL_(Bytes)'] = clean_data['Google_UL_(Bytes)'] + clean_data['Google_DL_(Bytes)']
clean_data['Social Media_UL_and_DL_(Bytes)'] = clean_data['Social_Media_UL_(Bytes)'] + clean_data['Social_Media_DL_(Bytes)']
clean_data.head()
# Out:
#                Bearer_Id            Start  Start_ms              End  End_ms  \
# 0 13114483460844900352.0   4/4/2019 12:01     770.0  4/25/2019 14:35   662.0
# 1 13114483482878900224.0   4/9/2019 13:04     235.0   4/25/2019 8:15   606.0
# 2 13114483484080500736.0   4/9/2019 17:42       1.0  4/25/2019 11:58   652.0
# 3 13114483485442799616.0   4/10/2019 0:31     486.0   4/25/2019 7:36   171.0
# 4 13114483499480700928.0  4/12/2019 20:10     565.0  4/25/2019 10:40   954.0
#
#      Dur_ms              IMSI  MSISDN_Number             IMEI  \
# 0 1823652.0 208201448079117.0  33664962239.0 35521209507511.0
# 1 1365104.0 208201909211140.0  33681854413.0 35794009006359.0
# 2 1361762.0 208200314458056.0  33760627129.0 35281510359387.0
# 3 1321509.0 208201402342131.0  33750343200.0 35356610164913.0
# 4 1089009.0 208201401415120.0  33699795932.0 35407009745539.0
#
#       Last_Location_Name  ...  Total_UL_(Bytes)  Total_DL_(Bytes)  \
# ...

# %%
#Selecting a few of the columns for overview analysis of the user behaviour

user_columns = ['Bearer_Id','Dur_ms','MSISDN_Number','Total_UL_and_DL_(Bytes)','Other_UL_and_DL_(Bytes)',
                'Gaming_UL_and_DL_(Bytes)','Netflix_UL_and_DL_(Bytes)','Youtube_UL_and_DL_(Bytes)',
                'Email_UL_and_DL_(Bytes)','Google_UL_and_DL_(Bytes)','Social Media_UL_and_DL_(Bytes)']

user_overview_data = clean_data[user_columns]
user_overview_data.head()
# Out:
#                Bearer_Id    Dur_ms  MSISDN_Number  Total_UL_and_DL_(Bytes)  \
# 0 13114483460844900352.0 1823652.0  33664962239.0              345629377.0
# 1 13114483482878900224.0 1365104.0  33681854413.0              707185356.0
# 2 13114483484080500736.0 1361762.0  33760627129.0              307690973.0
# 3 13114483485442799616.0 1321509.0  33750343200.0              889352748.0
# 4 13114483499480700928.0 1089009.0  33699795932.0              607681403.0
#
#    Other_UL_and_DL_(Bytes)  Gaming_UL_and_DL_(Bytes)  \
# 0              180558843.0               292426453.0
# 1              541959383.0               609920783.0
# 2              414908351.0               229980251.0
# 3              761837216.0               810387875.0
# 4              564619822.0               531237049.0
#
#    Netflix_UL_and_DL_(Bytes)  Youtube_UL_and_DL_(Bytes)  \
# 0                 17855187.0                 18355943.0
# 1                 35565545.0                 39359124.0
# ...

# %%
user_overview_data.to_csv('../data/user_overview_data.csv',index=False)

# %%
type(user_overview_data['Total_UL_and_DL_(Bytes)'][0])
# Out:
# numpy.float64

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# Converting the data capacity from bytes to Megabytes
for column in user_columns:
    if column not in ['Bearer_Id','Dur_ms','MSISDN_Number']:
        user_overview_data[column]= user_overview_data[column]/(10**6)

user_overview_data.head()
# Out:
#                Bearer_Id    Dur_ms  MSISDN_Number  Total_UL_and_DL_(Bytes)  \
# 0 13114483460844900352.0 1823652.0  33664962239.0                    345.6
# 1 13114483482878900224.0 1365104.0  33681854413.0                    707.2
# 2 13114483484080500736.0 1361762.0  33760627129.0                    307.7
# 3 13114483485442799616.0 1321509.0  33750343200.0                    889.4
# 4 13114483499480700928.0 1089009.0  33699795932.0                    607.7
#
#    Other_UL_and_DL_(Bytes)  Gaming_UL_and_DL_(Bytes)  \
# 0                    180.6                     292.4
# 1                    542.0                     609.9
# 2                    414.9                     230.0
# 3                    761.8                     810.4
# 4                    564.6                     531.2
#
#    Netflix_UL_and_DL_(Bytes)  Youtube_UL_and_DL_(Bytes)  \
# 0                       17.9                       18.4
# 1                       35.6                       39.4
# ...

# %%
#Aggregating all column data about every user
users = user_overview_data.groupby(['MSISDN_Number'])#First group the data by user
users_aggregated = users.agg({'Bearer_Id':'count','Dur_ms':'sum','Total_UL_and_DL_(Bytes)':'sum',
                              'Other_UL_and_DL_(Bytes)':'sum','Gaming_UL_and_DL_(Bytes)':'sum',
                              'Netflix_UL_and_DL_(Bytes)':'sum','Youtube_UL_and_DL_(Bytes)':'sum',
                              'Email_UL_and_DL_(Bytes)':'sum','Google_UL_and_DL_(Bytes)':'sum',
                              'Social Media_UL_and_DL_(Bytes)':'sum'})
users_aggregated
# Out:
#                    Bearer_Id     Dur_ms  Total_UL_and_DL_(Bytes)  \
# MSISDN_Number
# 33601001722.0              1   116720.0                    878.7
# 33601001754.0              1   181230.0                    156.9
# 33601002511.0              1   134969.0                    596.0
# 33601007832.0              1    49878.0                    422.3
# 33601008617.0              2    37104.0                   1457.4
# ...                      ...        ...                      ...
# 33789997247.0              1   140988.0                    480.3
# 41882819545.0           1066 72551004.6                 531744.7
# 3197020876596.0            1   877385.0                    232.1
# 337000037000919.0          1   253030.0                    596.3
# 882397108489451.0          1   869844.0                    139.2
#
#                    Other_UL_and_DL_(Bytes)  Gaming_UL_and_DL_(Bytes)  \
# MSISDN_Number
# 33601001722.0                        386.6                     812.5
# ...

# %%
'''Describing all relevant variables and associated data types'''
user_overview_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150001 entries, 0 to 150000
# Data columns (total 11 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   Bearer_Id                       150001 non-null  float64
#  1   Dur_ms                          150001 non-null  float64
#  2   MSISDN_Number                   150001 non-null  float64
#  3   Total_UL_and_DL_(Bytes)         150001 non-null  float64
#  4   Other_UL_and_DL_(Bytes)         150001 non-null  float64
#  5   Gaming_UL_and_DL_(Bytes)        150001 non-null  float64
#  6   Netflix_UL_and_DL_(Bytes)       150001 non-null  float64
#  7   Youtube_UL_and_DL_(Bytes)       150001 non-null  float64
#  8   Email_UL_and_DL_(Bytes)         150001 non-null  float64
#  9   Google_UL_and_DL_(Bytes)        150001 non-null  float64
#  10  Social Media_UL_and_DL_(Bytes)  150001 non-null  float64
# dtypes: float64(11)
# memory usage: 12.6 MB

# %% [markdown]
# Basically, the:
#
#     Bearer_Id Identifies the session that particular call was on
#     Dur_ms*Determines the duration of the user's engagement with the telecommunication company
#     MSISDN_Number Is the unique customer Identifier (Their mobile number)
#     The other variables describe the total data received and sent across those different media for each user

# %% [markdown]
# ## NON-GRAPHICAL UNIVARIATE ANALYSIS

# %%
#Fixing identified outlier
def fix_outlier(df, column):
    df[column] = np.where(df[column] > df[column].quantile(0.95), df[column].median(),df[column])
    
    return df[column]


user_overview_data['Dur_ms']=fix_outlier(user_overview_data,'Dur_ms')
user_overview_data['Total_UL_and_DL_(Bytes)']=fix_outlier(user_overview_data,'Total_UL_and_DL_(Bytes)')
user_overview_data['Other_UL_and_DL_(Bytes)']=fix_outlier(user_overview_data,'Other_UL_and_DL_(Bytes)')
user_overview_data['Gaming_UL_and_DL_(Bytes)']=fix_outlier(user_overview_data,'Gaming_UL_and_DL_(Bytes)')
user_overview_data['Netflix_UL_and_DL_(Bytes)']=fix_outlier(user_overview_data,'Netflix_UL_and_DL_(Bytes)')
user_overview_data['Youtube_UL_and_DL_(Bytes)']=fix_outlier(user_overview_data,'Youtube_UL_and_DL_(Bytes)')
user_overview_data['Email_UL_and_DL_(Bytes)']=fix_outlier(user_overview_data,'Email_UL_and_DL_(Bytes)')
user_overview_data['Google_UL_and_DL_(Bytes)']=fix_outlier(user_overview_data,'Google_UL_and_DL_(Bytes)')
user_overview_data['Social_Media_UL_and_DL_(Bytes)']=fix_outlier(user_overview_data,'Social_Media_UL_and_DL_(Bytes)')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\10_acad\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Social_Media_UL_and_DL_(Bytes)'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-93dbcbb1a363> in <module>
# ...

# %%
#Analyzing the basic metric for interpretation of their importance for global objectives
user_overview_data.describe()

# %% [markdown]
# ### Interpretation
# The data used in the media have high standard diviation - This clearly explains that users have a high variation in the amount of data sent and received. The data is soo much dispersed with relation to the mean for the majority of the variables
#
# Email data and Social media is however not soo much dispersed hence the majority of the people send and receive almost equal amount of data
#
# Duration of the call is also soo much dispersed

# %%
# Non-graphical univariate analysis of Bearer_Id

users_aggregated['Bearer_Id'].describe()

# %%
# Non-graphical univariate analysis of Dur_ms

users_aggregated['Dur_ms'].describe()

# %%
# Non-graphical univariate analysis of Total_UL_and_DL_(Bytes)

users_aggregated['Total_UL_and_DL_(Bytes)'].describe()

# %%
# Non-graphical univariate analysis of Gaming_UL_and_DL_(Bytes)

users_aggregated['Gaming_UL_and_DL_(Bytes)'].describe()

# %%
# Non-graphical univariate analysis of Netflix_UL_and_DL_(Bytes)

users_aggregated['Netflix_UL_and_DL_(Bytes)'].describe()

# %%
# Non-graphical univariate analysis of Youtube_UL_and_DL_(Bytes)

users_aggregated['Youtube_UL_and_DL_(Bytes)'].describe()

# %%
# Non-graphical univariate analysis of Gaming_UL_and_DL_(Bytes)

users_aggregated['Gaming_UL_and_DL_(Bytes)'].describe()

# %%
# Non-graphical univariate analysis of Email_UL_and_DL_(Bytes)

users_aggregated['Email_UL_and_DL_(Bytes)'].describe()

# %%
# Non-graphical univariate analysis of Google_UL_and_DL_(Bytes)

users_aggregated['Google_UL_and_DL_(Bytes)'].describe()

# %%
###################################PLOTTING FUNCTIONS###################################

def plot_hist(df:pd.DataFrame, column:str, color:str)->None:
    plt.figure(figsize=(15, 10))
    fig, ax = plt.subplots(1, figsize=(12, 7))
    sns.displot(data=df, x=column, color=color, kde=True, height=7, aspect=2)
    plt.title(f'Distribution of {column}', size=20, fontweight='bold')
    plt.show()

def plot_count(df:pd.DataFrame, column:str) -> None:
    plt.figure(figsize=(12, 7))
    sns.countplot(data=df, x=column)
    plt.title(f'Distribution of {column}', size=20, fontweight='bold')
    plt.show()
    
def plot_bar(df:pd.DataFrame, x_col:str, y_col:str, title:str, xlabel:str, ylabel:str)->None:
    plt.figure(figsize=(12, 7))
    sns.barplot(data = df, x=x_col, y=y_col)
    plt.title(title, size=20)
    plt.xticks(rotation=75, fontsize=14)
    plt.yticks( fontsize=14)
    plt.xlabel(xlabel, fontsize=16)
    plt.ylabel(ylabel, fontsize=16)
    plt.show()

def plot_heatmap(df:pd.DataFrame, title:str, cbar=False)->None:
    plt.figure(figsize=(12, 7))
    sns.heatmap(df, annot=True, cmap='viridis', vmin=0, vmax=1, fmt='.2f', linewidths=.7, cbar=cbar )
    plt.title(title, size=18, fontweight='bold')
    plt.show()

def plot_box(df:pd.DataFrame, x_col:str, title:str) -> None:
    plt.figure(figsize=(12, 7))
    sns.boxplot(data = df, x=x_col)
    plt.title(title, size=20)
    plt.xticks(rotation=75, fontsize=14)
    plt.show()

def plot_box_multi(df:pd.DataFrame, x_col:str, y_col:str, title:str) -> None:
    plt.figure(figsize=(12, 7))
    sns.boxplot(data = df, x=x_col, y=y_col)
    plt.title(title, size=20)
    plt.xticks(rotation=75, fontsize=14)
    plt.yticks( fontsize=14)
    plt.show()

def plot_scatter(df: pd.DataFrame, x_col: str, y_col: str, title: str) -> None:
    plt.figure(figsize=(12, 7))
    sns.scatterplot(data = df, x=x_col, y=y_col)
    plt.title(title, size=20)
    plt.xticks(fontsize=14)
    plt.yticks( fontsize=14)
    plt.show()
    
def plot_univariate(df, col1, col2):
    plt.figure(figsize = (20, 15))

    plt.subplot(2, 2, 1)
    plt.hist(df[col1], bins = 20, color = 'green', edgecolor = 'gray', linewidth = 0.5)
    plt.title(f'Histogram of {col1}', size=14)

    plt.subplot(2, 2, 2)
    plt.boxplot(df[col1])
    plt.title(f'Boxplot of {col1}', size=14)

    plt.subplot(2, 2, 3)
    plt.hist(df[col2], bins=20, color='green', edgecolor='gray', linewidth=0.5)
    plt.title(f'Histogram of {col2}', size=14)

    plt.subplot(2, 2, 4)
    plt.boxplot(df[col2])
    plt.title(f'Boxplot of {col2}', size=14)
    
       

    plt.show()

# %%
#Plotting the univariate Graphical Interpretation

plot_univariate(user_overview_data,'Dur_ms','Total_UL_and_DL_(Bytes)')
plot_univariate(user_overview_data,'Other_UL_and_DL_(Bytes)','Gaming_UL_and_DL_(Bytes)')
plot_univariate(user_overview_data,'Netflix_UL_and_DL_(Bytes)','Youtube_UL_and_DL_(Bytes)')
plot_univariate(user_overview_data,'Email_UL_and_DL_(Bytes)','Google_UL_and_DL_(Bytes)')
plot_univariate(user_overview_data,'Gaming_UL_and_DL_(Bytes)')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-1f27e88e590f> in <module>
#       5 plot_univariate(user_overview_data,'Netflix_UL_and_DL_(Bytes)','Youtube_UL_and_DL_(Bytes)')
#       6 plot_univariate(user_overview_data,'Email_UL_and_DL_(Bytes)','Google_UL_and_DL_(Bytes)')
# ----> 7 plot_univariate(user_overview_data,'Gaming_UL_and_DL_(Bytes)')
#
# TypeError: plot_univariate() missing 1 required positional argument: 'col2'

# %% [markdown]
# ## Conducting Bivariate Analysis

# %%
#Bivariate analysis of social media data to the total data
plot_scatter(user_overview_data.sample(300), x_col="Social_Media_UL_and_DL_(Bytes)", y_col='Total_UL_and_DL_(Bytes)', title="Total UL_DL vs Social UL_DL")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-b7cb36ee8c5a> in <module>
#       1 #Bivariate analysis of social media data to the total data
# ----> 2 plot_scatter(user_overview_data.sample(300), x_col="Social_Media_UL_and_DL_(Bytes)", y_col='Total_UL_and_DL_(Bytes)', title="Total UL_DL vs Social UL_DL")
#
# <ipython-input-33-f807be443a50> in plot_scatter(df, x_col, y_col, title)
#      47 def plot_scatter(df: pd.DataFrame, x_col: str, y_col: str, title: str) -> None:
#      48     plt.figure(figsize=(12, 7))
# ---> 49     sns.scatterplot(data = df, x=x_col, y=y_col)
#      50     plt.title(title, size=20)
#      51     plt.xticks(fontsize=14)
#
# ~\anaconda3\envs\10_acad\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ...

# %%
#Bivariate analysis of Google_UL_and_D data to the total data
plot_scatter(user_overview_data.sample(300), x_col="Google_UL_and_DL_(Bytes)", y_col='Total_UL_and_DL_(Bytes)', 
             title="Total UL_DL vs 'Google_UL_and_DL_(Bytes)'")

# %%
#Bivariate analysis of Email_UL_and_DL data to the total data
plot_scatter(user_overview_data.sample(300), x_col='Email_UL_and_DL_(Bytes)', y_col='Total_UL_and_DL_(Bytes)', 
             title="Total UL_DL vs Email_UL_and_DL_(Bytes)")

# %%
#Bivariate analysis of Youtube_UL_and_DL to the total data
plot_scatter(user_overview_data.sample(300), x_col="Youtube_UL_and_DL_(Bytes)", y_col='Total_UL_and_DL_(Bytes)', 
             title="Total UL_DL vs Youtube_UL_and_DL_(Bytes)")

# %%
#Bivariate analysis of social media data to the total data
plot_scatter(user_overview_data.sample(300), x_col="Netflix_UL_and_DL_(Bytes)", y_col='Total_UL_and_DL_(Bytes)', 
             title="Total UL_DL vs Netflix_UL_and_DL_(Bytes)")

# %%
#Bivariate analysis of Gaming_UL_and_DL to the total data
plot_scatter(user_overview_data.sample(300), x_col="Gaming_UL_and_DL_(Bytes)", y_col='Total_UL_and_DL_(Bytes)', 
             title="Total UL_DL vs Gaming_UL_and_DL_(Bytes)")

# %% [markdown]
# In the game data analysis with respect to the total data, we get to find that an increase in the amount of  data usage linearly results to an increase in the total amount of data. We can therefore predict the total amount of data depending on the gaming data generated

# %%
#Bivariate analysis of Other_UL_and_DL to the total data
plot_scatter(user_overview_data.sample(300), x_col="Other_UL_and_DL_(Bytes)", y_col='Total_UL_and_DL_(Bytes)', 
             title="Total UL_DL vs Other_UL_and_DL_(Bytes))")

# %%
#Correlation of the required columns
correlated_columns = ['Total_UL_and_DL_(Bytes)','Other_UL_and_DL_(Bytes)','Gaming_UL_and_DL_(Bytes)','Netflix_UL_and_DL_(Bytes)','Youtube_UL_and_DL_(Bytes)','Email_UL_and_DL_(Bytes)','Google_UL_and_DL_(Bytes)','Social Media_UL_and_DL_(Bytes)']
sample_data_for_correlation = user_overview_data[correlated_columns]
pd.set_option('display.float_format', lambda x: '%.3f' % x)
correlated = sample_data_for_correlation.corr()
correlated

# %%
import pandas as pd


class Overview:
    def __init__(self, df) -> None:
        self.df = df

    # Function to calculate missing values by column
    def missing_values_table(self):
        # Total missing values
        mis_val = self.df.isnull().sum()

        # Percentage of missing values in each column with respect to the total number 
        # of rows
        mis_val_percent = 100 * self.df.isnull().sum() / len(self.df)

        # dtype of missing values
        mis_val_dtype = self.df.dtypes

        # Make a table with the results
        mis_val_table = pd.concat([mis_val, mis_val_percent, mis_val_dtype], axis=1)

        # Rename the columns
        mis_val_table_ren_columns = mis_val_table.rename(
        columns = {0 : 'Missing Values', 1 : '% of Total Values', 2: 'Dtype'})

        # Sort the table by percentage of missing descending
        mis_val_table_ren_columns = mis_val_table_ren_columns[
            mis_val_table_ren_columns.iloc[:,1] != 0].sort_values(
        by='% of Total Values', ascending=False).round(1)

        # Print some summary information
        print ("Your selected dataframe has " + str(self.df.shape[1]) + " columns.\n"      
            "There are " + str(mis_val_table_ren_columns.shape[0]) +
            " columns that have missing values.")

        # Return the dataframe with missing information
        return mis_val_table_ren_columns

# %%
ex = Overview(user_data)
ex.missing_values_table()
# Out:
# Your selected dataframe has 55 columns.
# There are 41 columns that have missing values.
#                                           Missing Values  % of Total Values  \
# Nb of sec with 37500B < Vol UL                    130254               86.8
# Nb of sec with 6250B < Vol UL < 37500B            111843               74.6
# Nb of sec with 125000B < Vol DL                    97538               65.0
# TCP UL Retrans. Vol (Bytes)                        96649               64.4
# Nb of sec with 31250B < Vol DL < 125000B           93586               62.4
# Nb of sec with 1250B < Vol UL < 6250B              92894               61.9
# Nb of sec with 6250B < Vol DL < 31250B             88317               58.9
# TCP DL Retrans. Vol (Bytes)                        88146               58.8
# HTTP UL (Bytes)                                    81810               54.5
# HTTP DL (Bytes)                                    81474               54.3
# ...
